# %%
from flask import Flask, render_template, request
import pandas as pd
import mysql.connector
import os

app = Flask(__name__)

def get_db_connection():
    connection = mysql.connector.connect(
        host='quote.c9ac6sewqau0.ap-southeast-2.rds.amazonaws.com',
        database='quote',
        user='admin',
        password='admin123'
    )
    return connection

def query_data_dataframe(query):
    connection = get_db_connection()
    try:
        df = pd.read_sql_query(query, connection)
        return df
    finally:
        if connection.is_connected():
            connection.close()

@app.route('/')
def index():
    query = "SELECT * FROM Tradeasy_quotation"
    df = query_data_dataframe(query)
    return render_template('index.html', tables=[df.to_html(classes='table table-striped', header="true", index=False)])


if __name__ == '__main__':
    app.run(debug=False)

# %%
query = "SELECT * FROM Tradeasy_quotation"
df = query_data_dataframe(query)
# Out:
# /var/folders/cp/b4jcf1z12td5hcrynb9qkxtm0000gn/T/ipykernel_1042/2627010789.py:19: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df = pd.read_sql_query(query, connection)

# %%
# Out:
#    id              productName          productTag            supplier  \
# 0   1   Frozen Atlantic Salmon       Fish - Frozen    Oceanic Seafoods
# 1   2   Organic Chicken Breast     Poultry - Fresh   Farmstead Poultry
# 2   3  Angus Beef Ribeye Steak      Beef - Premium  Quality Meats Ltd.
# 3   4       Jumbo Tiger Shrimp    Seafood - Frozen          Blue Ocean
# 4   5         Mixed Vegetables    Veggies - Frozen       Green Harvest
# 5   6          Lamb Loin Chops        Lamb - Fresh    Shepherd’s Pride
# 6   7            Pork Sausages    Pork - Breakfast          Daily Deli
# 7   8    Italian Fusilli Pasta         Pasta - Dry        Global Foods
# 8   9              Blue Cheese      Cheese - Dairy     Cheese Crafters
# 9  10             Spicy Kimchi  Kimchi - Fermented      Ferment Valley
#
#      category          packing       origin          brand effectiveDate  \
# 0        Fish    Vacuum Packed       Norway        SeaKing    2023-03-01
# ...

# %%
if __name__ == '__main__':
    app.run(debug=False)
# Out:
#  * Serving Flask app '__main__'
#  * Debug mode: off
# WARNING: This is a development server. Do not use it in a production deployment. Use a production WSGI server instead.
#  * Running on http://127.0.0.1:5000
# Press CTRL+C to quit
# /var/folders/cp/b4jcf1z12td5hcrynb9qkxtm0000gn/T/ipykernel_1139/1227692838.py:20: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df = pd.read_sql_query(query, connection)
# 127.0.0.1 - - [14/Mar/2024 15:48:58] "GET / HTTP/1.1" 200 -
